# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls /content/gdrive/'My Drive'/'Colab Notebooks'/review_data/
# Out:
# extreme_job_review2.txt  test_data_12.csv  test_data_14.csv
# test_data_11.csv         test_data_13.csv

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# fatal: destination path 'Mecab-ko-for-Google-Colab' already exists and is not an empty directory.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.3)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.8.0)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.17.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2020-01-16 08:39:52--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.2, 18.205.93.1, 18.205.93.0, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=uueqr8vV2V4zVFMpB9GLuYqY7v4%3D&Expires=1579165608&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22 [following]
# --2020-01-16 08:39:52--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=uueqr8vV2V4zVFMpB9GLuYqY7v4%3D&Expires=1579165608&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.179.107
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.179.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz.1’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  2.70MB/s    in 0.5s
#
# 2020-01-16 08:39:53 (2.70 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz.1’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2020-01-16 08:40:10--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.2, 18.205.93.1, 18.205.93.0, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=GKO%2FZG%2FrrEnJEJ7MysptwDvN5Pw%3D&Expires=1579165680&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22 [following]
# --2020-01-16 08:40:10--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=GKO%2FZG%2FrrEnJEJ7MysptwDvN5Pw%3D&Expires=1579165680&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.232.219
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.232.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz.1’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  27.9MB/s    in 1.7s
#
# 2020-01-16 08:40:12 (27.9 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz.1’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()

# %%
import MeCab
import pandas as pd
import numpy as np

# %%
tagger = MeCab.Tagger()
with open('/content/gdrive/My Drive/Colab Notebooks/review_data/extreme_job_review2.txt','r',encoding='utf-8') as f:
    my_sentence=f.read()
my_sentence
# Out:
# '<아 재밌다!! 또 봐야지!!>\n코미디 영화의 미덕은 뭐니 뭐니 해도 웃기는 거다.\n다만 그 소재와 방법이 개개인의 취향에 들어맞느냐가 관건인데 이 영화는 딱 내 취향이었다.\n스물로 코미디 영화의 장인이라는 이미지가 각인된 이병헌 감독의 작품답게 작정하고 웃기려는 시도가 영화 내내 이어진다. 근데 이게 참 타율이 무척 높다.\n초반에는 너무 뻔하다 싶었던 개그코드들이 중반을 넘어서 후반으로 가면서부터 캐릭터와 상황들과 잘 맞아떨어지면서 웃음폭탄이 터진다. 별거 아닐 수도 있고 병맛일수도 있는데 그냥 막무가내로 웃긴다.\n그냥 생각 없이, 혹은 가볍게 웃을 수 있는 영화를 찾는다면 딱일 듯!!!\n배우들의 연기와 캐릭터도 참 좋았다.\n류승룡 배우는 드디어 딱 맞는 옷을 입은 듯... 염력에선 영화와 맞지 않는 옷을 입은듯했지만 이 영화에선 찰떡이었다. 특히나 후반부에서 터지는 액션과 개그는 정신 못 차리고 웃게 만든다ㅋㅋㅋㅋ\n개인적으로 가장 큰 수확이었던 건 진선규 배우의 캐릭터.\n왠지 모르게 떠오르는 이미지가 있는데 그걸 억지로 비틀지 않고 교묘히 잘 사용해서 웃음을 터트린다.\n믿음직한 조연으로 잘 자리 잡아가는 거 같아서 괜히 흐뭇...\n이하늬 배우는 솔직히 큰 기대 안 했는데 진선규 배우와의 호흡이 너무 좋았다. \n다소 거칠고 털털한 캐릭터를 잘 살려준 듯...\n이동휘 배우는 기대보단 못했던 활약이지만 캐릭터의 성향상 그게 맞는듯한데 그래도 특유의 개그감은 잃지 않은 듯...\n공명 배우는 이번에 처음 봤는데 이름을 기억하게 될 정도로 연기가 인상 깊었다.\n특히나 후반부 액션신에선 씬스틸러였음ㅋㅋㅋㅋㅋ\n악역으로 등장했던 신하균, 오정세 배우들도 역시나 이름에 걸맞은 연기 잘 보여주었고...\n개그라는 게 취향 차이가 심해서 무조건적으로 추천할 순 없지만 시사회 끝나고 나가는 관객들의 반응을 보니 구정 연휴에 관객몰이 제대로 할 거 같은 기분이 들기도 한다. \n적어도 나는 조카들 데리고 한번 더 볼 생각이니까 ㅋㅋㅋ\n웃으라고 작정하고 만든 영화가 웃게 만들어주니 기분이 좋다.\n개그코드만 맞아떨어지면 그야말로 눈물 날 정도로 웃다 나올 듯.\n코미디빅리그에서  개그코너중에\n형사인데 잠복근무 한다고\n수배범 단골집같은곳에 알바로 잠복하는데\n이집 맛집이야... 장사가 너무잘되\n아침에 출근해서 저녁까지 쉴틈이 없어...\n집에가면 지쳐서 골아떨어져...\n조사를 어떻게해...\n내가 형사인지 여기 알바생인지 헷갈릴때가 있어\n이런 개그코너있는데   코미디빅리그 - 잠입수사 라는 코너인데...\n그거랑 너무 흡사하네요\n거기서 아이디어 따오신거 맞나요\n제가볼땐 뭔가 노잼삘이 나는거같습니다...\n영화를 볼바에  코미디빅리그에서 나온거 보는게 더 재밌을수도있겠네요 \n진짜 첨부터 끝까지 지루함 1도 없었음 주인공들도 발암캐릭터 하나도 없음 개봉하면 또보러 갈예정\n연기잘하고 내용 재밌고 기대이상이였던 영화! 영화들 중간에 지루한 부분이 거의 대부분인데 이건 지루함 없이 끝까지 재밌게 본거같음 최근 본 영화중 제일 좋았음 !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\n영화 "내 아내의 모든 것" 이후 \'극한직업\'으로 다시 배우 류승룡이 전국민을 웃음바다로 만들듯 합니다.\n마약조직 검거를 위해 치킨집에 잠복했다 치킨집을 인수하면서 벌어지는 해프닝 속에\n배우 류승룡 뿐만 아니라 최근 악역으로 인상적인 연기를 보였던 진선규, 대한민국 대표미녀 이하늬\n완전히 웃기는 표정 컨셉으로 관객의 배꼽을 보는 내내 째는 이동휘, 그리고 잘생긴 막내  공명\n이 5명 마약단속반이 펼치는 홍콩 코믹 스타일의 한국 영화였습니다\n보는 동안 주성치 영화가 많이 생각났고요 이병헌 감독도 영화에 잠시 홍콩영화의 유명 음악을\n삽입하며 알만한 사람들은 느낄만한 홍콩영화들의 한국적 재해석을 드러내내요.\n배우 류승룡씨의 코메디 연기는 영화 "내 아내의 모든 것"에서 이미 봤듯이 뭔가 특별한 느낌이 있죠\n영화 중간 중간 왠지 너무 웃기려고 하면 무게를 잡아주는 악역 신하균씨 연기도 좋았습니다.\n류승룡이 앰블런스에 실리기 전 이동휘에게 하염없이 "쏴" "쏴" 외치며 관객의 배꼽을 마지막까지 째는\n류승룡 진선규 이하늬 이동휘 공명 그리고 신하균이 펼치는 코미디 무비 \n부부끼리 가서 봐도 좋겠고, 가족끼리 가도 좋겠습니다.\n"극한직업" 강추합니다.    '

# %%
print(tagger.parse(my_sentence))
# Out:
# <	SY,*,*,*,*,*,*,*
# 아	IC,*,F,아,*,*,*,*
# 재밌	VA,*,T,재밌,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SY,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 봐야지	VV+EF,*,F,봐야지,Inflect,VV,EF,보/VV/*+ㅏ야지/EF/*
# !	SF,*,*,*,*,*,*,*
# !>	SY,*,*,*,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 미덕	NNG,정적사태,T,미덕,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 뭐	NP,*,F,뭐,Inflect,NP,NP,뭣/NP/*
# 니	VCP+EC,*,F,니,Inflect,VCP,EC,이/VCP/*+니/EC/*
# 뭐	NP,*,F,뭐,Inflect,NP,NP,뭣/NP/*
# 니	VCP+EC,*,F,니,Inflect,VCP,EC,이/VCP/*+니/EC/*
# 해도	VV+EC,*,F,해도,Inflect,VV,EC,하/VV/*+아도/EC/*
# 웃기	VV,*,F,웃기,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 거	NNB,*,F,거,*,*,*,*
# 다	VCP+EF,*,F,다,Inflect,VCP,EF,이/VCP/*+다/EF/*
# .	SF,*,*,*,*,*,*,*
# 다만	MAJ,*,T,다만,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 소재	NNG,*,F,소재,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 방법	NNG,*,T,방법,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 개개인	NNG,*,T,개개인,Compound,*,*,개개/NNG/*+인/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 취향	NNG,*,T,취향,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 들어맞	VV,*,T,들어맞,*,*,*,*
# 느냐	EC,*,F,느냐,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 관건	NNG,*,T,관건,*,*,*,*
# 인데	VCP+EC,*,F,인데,Inflect,VCP,EC,이/VCP/*+ᆫ데/EC/*
# 이	MM,~명사,F,이,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 딱	MAG,*,T,딱,*,*,*,*
# 내	NP+JKG,*,F,내,Inflect,NP,JKG,나/NP/*+의/JKG/*
# 취향	NNG,*,T,취향,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 스물	NR,*,T,스물,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 장인	NNG,*,T,장인,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라는	ETM,*,T,라는,*,*,*,*
# 이미지	NNG,*,F,이미지,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 각인	NNG,*,T,각인,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 이병헌	NNP,인명,T,이병헌,*,*,*,*
# 감독	NNG,*,T,감독,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 작품	NNG,*,T,작품,*,*,*,*
# 답	XSA,*,T,답,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 작정	NNG,행위,T,작정,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 웃기	VV,*,F,웃기,*,*,*,*
# 려는	ETM,*,T,려는,*,*,*,*
# 시도	NNG,*,F,시도,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 내내	MAG,성분부사|시간부사,F,내내,*,*,*,*
# 이어진다	VV+EF,*,F,이어진다,Inflect,VV,EF,이어지/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 근데	MAJ,*,F,근데,*,*,*,*
# 이게	NP+JKS,*,F,이게,Inflect,NP,JKS,이것/NP/*+이/JKS/*
# 참	MAG,성분부사|정도부사,T,참,*,*,*,*
# 타율	NNG,*,T,타율,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 무척	MAG,성분부사|정도부사,T,무척,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 초반	NNG,*,T,초반,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 뻔하	VA,*,F,뻔하,*,*,*,*
# 다	EC,*,F,다,*,*,*,*
# 싶	VX,*,T,싶,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 코드	NNG,*,F,코드,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 중반	NNG,*,T,중반,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 넘	VV,*,T,넘,*,*,*,*
# 어서	EC,*,F,어서,*,*,*,*
# 후반	NNG,*,T,후반,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 가	VV,*,F,가,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# 부터	JX,*,F,부터,*,*,*,*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 상황	NNG,정적사태,T,상황,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 과	JKB,*,F,과,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 맞아떨어지	VV,*,F,맞아떨어지,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# 웃음	NNG,행위,T,웃음,Compound,*,*,웃/NNG/*+음/NNG/*
# 폭탄	NNG,*,T,폭탄,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 터진다	VV+EF,*,F,터진다,Inflect,VV,EF,터지/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 별거	NNG,*,F,별거,Compound,*,*,별/NNG/*+거/NNG/*
# 아닐	VCN+ETM,*,T,아닐,Inflect,VCN,ETM,아니/VCN/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 병맛	NNG,*,T,병맛,*,*,*,*
# 일	VCP+ETM,*,T,일,Inflect,VCP,ETM,이/VCP/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# 그냥	MAG,성분부사|양태부사,T,그냥,*,*,*,*
# 막무가내	NNG,행위,F,막무가내,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 웃긴다	VV+EF,*,F,웃긴다,Inflect,VV,EF,웃기/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 그냥	MAG,성분부사|양태부사,T,그냥,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 없이	MAG,성분부사|양태부사,F,없이,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 혹은	MAJ,*,T,혹은,*,*,*,*
# 가볍	VA,*,T,가볍,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 웃	VV,*,T,웃,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 찾	VV,*,T,찾,*,*,*,*
# 는다면	EC,*,T,는다면,*,*,*,*
# 딱	MAG,*,T,딱,*,*,*,*
# 일	VCP+ETM,*,T,일,Inflect,VCP,ETM,이/VCP/*+ᆯ/ETM/*
# 듯	NNB,*,T,듯,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !!	SY,*,*,*,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 참	MAG,성분부사|정도부사,T,참,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 드디어	MAG,성분부사|시간부사,F,드디어,*,*,*,*
# 딱	MAG,*,T,딱,*,*,*,*
# 맞	VV,*,T,맞,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 옷	NNG,*,T,옷,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 입	VV,*,T,입,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 듯	NNB,*,T,듯,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 염력	NNG,*,T,염력,*,*,*,*
# 에선	JKB+JX,*,T,에선,Inflect,JKB,JX,에서/JKB/*+ᆫ/JX/*
# 영화	NNG,*,F,영화,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 맞	VV,*,T,맞,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 옷	NNG,*,T,옷,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 입	VV,*,T,입,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 듯	NNB,*,T,듯,*,*,*,*
# 했	XSA+EP,*,T,했,Inflect,XSA,EP,하/XSA/*+았/EP/*
# 지만	EC,*,T,지만,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 에선	JKB+JX,*,T,에선,Inflect,JKB,JX,에서/JKB/*+ᆫ/JX/*
# 찰떡	NNG,*,T,찰떡,Compound,*,*,찰/NNG/*+떡/NNG/*
# 이	VCP,*,F,이,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 특히	MAG,성분부사|정도부사,F,특히,*,*,*,*
# 나	JX,*,F,나,*,*,*,*
# 후반부	NNG,*,F,후반부,Compound,*,*,후반/NNG/*+부/NNG/*
# 에서	JKB,*,F,에서,*,*,*,*
# 터지	VV,*,F,터지,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 액션	NNG,행위,T,액션,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 정신	NNG,*,T,정신,*,*,*,*
# 못	MAG,성분부사|부정부사,T,못,*,*,*,*
# 차리	VV,*,F,차리,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 웃	VV,*,T,웃,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 만든다	VV+EC,*,F,만든다,Inflect,VV,EC,만들/VV/*+ᆫ다/EC/*
# ㅋㅋ	IC,*,F,크크,*,*,*,*
# ㅋㅋ	IC,*,F,크크,*,*,*,*
# 개인	NNG,*,T,개인,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 가장	MAG,성분부사|정도부사,T,가장,*,*,*,*
# 큰	VA+ETM,*,T,큰,Inflect,VA,ETM,크/VA/*+ᆫ/ETM/*
# 수확	NNG,*,T,수확,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 건	NNB+JX,*,T,건,Inflect,NNB,JX,것/NNB/*+ᆫ/JX/*
# 진선규	NNP,인명,F,진선규,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 왠지	MAG,문장부사|양상부사,F,왠지,*,*,*,*
# 모르	VV,*,F,모르,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 떠오르	VV,*,F,떠오르,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이미지	NNG,*,F,이미지,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# 그걸	NP+JKO,*,T,그걸,Inflect,NP,JKO,그거/NP/*+ㄹ/JKO/*
# 억지로	MAG,성분부사|양태부사,F,억지로,*,*,*,*
# 비틀	VV,*,T,비틀,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 교묘히	MAG,성분부사|양태부사,F,교묘히,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# 웃음	NNG,행위,T,웃음,Compound,*,*,웃/NNG/*+음/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 터트린다	VV+EF,*,F,터트린다,Inflect,VV,EF,터트리/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 믿	VV,*,T,믿,*,*,*,*
# 음직	EC,*,T,음직,*,*,*,*
# 한	MM,~가산명사,T,한,*,*,*,*
# 조연	NNG,*,T,조연,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 자리	NNG,*,F,자리,*,*,*,*
# 잡아가	VV,*,F,잡아가,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 거	NNB,*,F,거,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 아서	EC,*,F,아서,*,*,*,*
# 괜히	MAG,성분부사|양태부사,F,괜히,*,*,*,*
# 흐뭇	XR,*,T,흐뭇,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 이하늬	NNP,인명,F,이하늬,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 솔직히	MAG,*,F,솔직히,*,*,*,*
# 큰	VA+ETM,*,T,큰,Inflect,VA,ETM,크/VA/*+ᆫ/ETM/*
# 기대	NNG,행위,F,기대,*,*,*,*
# 안	MAG,성분부사|부정부사,T,안,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 는데	EC,*,F,는데,*,*,*,*
# 진선규	NNP,인명,F,진선규,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 호흡	NNG,정적사태,T,호흡,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 다소	MAG,성분부사|정도부사,F,다소,*,*,*,*
# 거칠	VA,*,T,거칠,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 털털	XR,*,T,털털,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 살려	VV+EC,*,F,살려,Inflect,VV,EC,살리/VV/*+어/EC/*
# 준	VX+ETM,*,T,준,Inflect,VX,ETM,주/VX/*+ᆫ/ETM/*
# 듯	NNB,*,T,듯,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 이동휘	NNP,인명,F,이동휘,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 기대	NNG,행위,F,기대,*,*,*,*
# 보단	JKB+JX,*,T,보단,Inflect,JKB,JX,보다/JKB/*+ᆫ/JX/*
# 못	MAG,성분부사|부정부사,T,못,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 활약	NNG,행위,T,활약,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 성향	NNG,*,T,성향,*,*,*,*
# 상	XSN,*,T,상,*,*,*,*
# 그게	NP+JKS,*,F,그게,Inflect,NP,JKS,그것/NP/*+이/JKS/*
# 맞	VV,*,T,맞,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 듯	NNB,*,T,듯,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 데	NNB,*,F,데,*,*,*,*
# 그래도	VV+EC,*,F,그래도,Inflect,VV,EC,그러/VV/*+어도/EC/*
# 특유	NNG,정적사태,F,특유,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 감	XSN,*,T,감,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 잃	VV,*,T,잃,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 듯	NNB,*,T,듯,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 공명	NNG,*,T,공명,*,*,*,*
# 배우	VV,*,F,배우,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이번	NNG,*,T,이번,Compound,*,*,이/NNG/*+번/NNG/*
# 에	JKB,*,F,에,*,*,*,*
# 처음	MAG,*,T,처음,*,*,*,*
# 봤	VV+EP,*,T,봤,Inflect,VV,EP,보/VV/*+았/EP/*
# 는데	EC,*,F,는데,*,*,*,*
# 이름	NNG,*,T,이름,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 기억	NNG,행위,T,기억,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 될	VV+ETM,*,T,될,Inflect,VV,ETM,되/VV/*+ᆯ/ETM/*
# 정도	NNG,*,F,정도,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 인상	NNG,*,T,인상,*,*,*,*
# 깊	VA,*,T,깊,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 특히	MAG,성분부사|정도부사,F,특히,*,*,*,*
# 나	JX,*,F,나,*,*,*,*
# 후반부	NNG,*,F,후반부,Compound,*,*,후반/NNG/*+부/NNG/*
# 액션	NNG,행위,T,액션,*,*,*,*
# 신	NNG,*,T,신,*,*,*,*
# 에선	JKB+JX,*,T,에선,Inflect,JKB,JX,에서/JKB/*+ᆫ/JX/*
# 씬	NNP,인명,T,씬,*,*,*,*
# 스틸러	NNP,인명,F,스틸러,*,*,*,*
# 였	VCP+EP,*,T,였,Inflect,VCP,EP,이/VCP/*+었/EP/*
# 음	ETN,*,T,음,*,*,*,*
# ㅋㅋㅋ	IC,*,F,크크크,*,*,*,*
# ㅋㅋ	IC,*,F,크크,*,*,*,*
# 악역	NNG,*,T,악역,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 등장	NNG,상태변화,T,등장,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 신하균	NNP,인명,T,신하균,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 오정세	NNP,인명,F,오정세,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 역시	NNG,*,F,역시,*,*,*,*
# 나	JC,*,F,나,*,*,*,*
# 이름	NNG,*,T,이름,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 걸맞	VA,*,T,걸맞,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 보여	VV+EC,*,F,보여,Inflect,VV,EC,보이/VV/*+어/EC/*
# 주	VX,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 라는	VCP+ETM,*,T,라는,Inflect,VCP,ETM,이/VCP/*+라는/ETM/*
# 게	NNB+JKS,*,F,게,Inflect,NNB,JKS,것/NNB/*+이/JKS/*
# 취향	NNG,*,T,취향,*,*,*,*
# 차이	NNG,정적사태,F,차이,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 심해서	VA+EC,*,F,심해서,Inflect,VA,EC,심하/VA/*+아서/EC/*
# 무조건	NNG,*,T,무조건,Compound,*,*,무/NNG/*+조건/NNG/*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 추천	NNG,행위,T,추천,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 순	NNB+JX,*,T,순,Inflect,NNB,JX,수/NNB/*+ᆫ/JX/*
# 없	VA,*,T,없,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 시사회	NNG,*,F,시사회,Compound,*,*,시사/NNG/*+회/NNG/*
# 끝	NNG,*,T,끝,*,*,*,*
# 나	VV,*,F,나,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 나가	VX,*,F,나가,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 관객	NNG,*,T,관객,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 반응	NNG,*,T,반응,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 니	EC,*,F,니,*,*,*,*
# 구정	NNG,*,T,구정,*,*,*,*
# 연휴	NNG,*,F,연휴,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 관객	NNG,*,T,관객,*,*,*,*
# 몰	NNG,*,T,몰,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 제대로	MAG,성분부사|양태부사,F,제대로,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 기분	NNG,정적사태,T,기분,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 들	VV,*,T,들,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 한다	VV+EF,*,F,한다,Inflect,VV,EF,하/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 적어도	MAG,*,F,적어도,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 조카	NNG,*,F,조카,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 데리	VV,*,F,데리,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 한번	MAG,*,T,한번,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 볼	VV+ETM,*,T,볼,Inflect,VV,ETM,보/VV/*+ᆯ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 니까	EC,*,F,니까,*,*,*,*
# ㅋㅋㅋ	IC,*,F,크크크,*,*,*,*
# 웃	VV,*,T,웃,*,*,*,*
# 으라고	EC,*,F,으라고,*,*,*,*
# 작정	NNG,행위,T,작정,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 만든	VV+ETM,*,T,만든,Inflect,VV,ETM,만들/VV/*+ᆫ/ETM/*
# 영화	NNG,*,F,영화,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 웃	VV,*,T,웃,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 주	VX,*,F,주,*,*,*,*
# 니	EC,*,F,니,*,*,*,*
# 기분	NNG,정적사태,T,기분,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 코드	NNG,*,F,코드,*,*,*,*
# 만	JX,*,T,만,*,*,*,*
# 맞아떨어지	VV,*,F,맞아떨어지,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 그야말로	MAG,성분부사|정도부사,F,그야말로,*,*,*,*
# 눈물	NNG,*,T,눈물,Compound,*,*,눈/NNG/*+물/NNG/*
# 날	NNG,*,T,날,*,*,*,*
# 정도	NNG,*,F,정도,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 웃	VV,*,T,웃,*,*,*,*
# 다	EC,*,F,다,*,*,*,*
# 나올	VV+ETM,*,T,나올,Inflect,VV,ETM,나오/VV/*+ᆯ/ETM/*
# 듯	NNB,*,T,듯,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 빅리그	NNP,*,F,빅리그,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 코너	NNG,*,F,코너,*,*,*,*
# 중	NNB,*,T,중,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 형사	NNG,*,F,형사,*,*,*,*
# 인데	VCP+EC,*,F,인데,Inflect,VCP,EC,이/VCP/*+ᆫ데/EC/*
# 잠복근무	NNG,*,F,잠복근무,Compound,*,*,잠복/NNG/행위+근무/NNG/행위
# 한다고	VV+EC,*,F,한다고,Inflect,VV,EC,하/VV/*+ᆫ다고/EC/*
# 수배	NNG,행위,F,수배,*,*,*,*
# 범	XPN,*,T,범,*,*,*,*
# 단골집	NNG,*,T,단골집,Compound,*,*,단골/NNG/*+집/NNG/*
# 같	VA,*,T,같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 곳	NNG,*,T,곳,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 알바로	NNP,인명,F,알바로,*,*,*,*
# 잠복	NNG,행위,T,잠복,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 집	NNG,*,T,집,*,*,*,*
# 맛집	NNG,*,T,맛집,Compound,*,*,맛/NNG/*+집/NNG/*
# 이	VCP,*,F,이,*,*,*,*
# 야	EF,*,F,야,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 장사	NNG,*,F,장사,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 잘	VA,*,T,잘,*,*,*,*
# 되	EC,*,F,되,*,*,*,*
# 아침	NNG,*,T,아침,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 출근	NNG,행위,T,출근,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# 저녁	NNG,*,T,저녁,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 쉴	VV+ETM,*,T,쉴,Inflect,VV,ETM,쉬/VV/*+ᆯ/ETM/*
# 틈	NNG,*,T,틈,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 어	EF,*,F,어,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 집	NNG,장소,T,집,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 가	VV,*,F,가,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 지쳐서	VV+EC,*,F,지쳐서,Inflect,VV,EC,지치/VV/*+어서/EC/*
# 골	VV,*,T,골,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 떨어져	VV+EF,*,F,떨어져,Inflect,VV,EF,떨어지/VV/*+어/EF/*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 조사	NNG,*,F,조사,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 어떻게	MAG,*,F,어떻게,*,*,*,*
# 해	VV+EF,*,F,해,Inflect,VV,EF,하/VV/*+아/EF/*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 내	NP,*,F,내,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 형사	NNG,*,F,형사,*,*,*,*
# 인지	VCP+EC,*,F,인지,Inflect,VCP,EC,이/VCP/*+ᆫ지/EC/*
# 여기	NP,*,F,여기,*,*,*,*
# 알	VV+ETM,*,T,알,Inflect,VV,ETM,알/VV/*+ᆯ/ETM/*
# 바	NNB,*,F,바,*,*,*,*
# 생	XSN,*,T,생,*,*,*,*
# 인지	VCP+EC,*,F,인지,Inflect,VCP,EC,이/VCP/*+ᆫ지/EC/*
# 헷갈릴	VV+ETM,*,T,헷갈릴,Inflect,VV,ETM,헷갈리/VV/*+ᆯ/ETM/*
# 때	NNG,*,F,때,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 이런	MM,~명사,T,이런,*,*,*,*
# 개그	NNG,행위,F,개그,*,*,*,*
# 코너	NNG,*,F,코너,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 빅리그	NNP,*,F,빅리그,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# 잠입	NNG,행위,T,잠입,*,*,*,*
# 수사	NNG,*,F,수사,*,*,*,*
# 라는	VCP+ETM,*,T,라는,Inflect,VCP,ETM,이/VCP/*+라는/ETM/*
# 코너	NNG,*,F,코너,*,*,*,*
# 인데	VCP+EF,*,F,인데,Inflect,VCP,EF,이/VCP/*+ㄴ데/EF/*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 그거	NP,*,F,그거,Inflect,NP,NP,그것/NP/*
# 랑	JKB,*,T,랑,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 흡사	MAG,문장부사|양상부사,F,흡사,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 네요	EF,*,F,네요,*,*,*,*
# 거기	NP,*,F,거기,*,*,*,*
# 서	JKB,*,F,서,*,*,*,*
# 아이디어	NNG,정적사태,F,아이디어,*,*,*,*
# 따오	VV,*,F,따오,*,*,*,*
# 신	EP+ETM,*,T,신,Inflect,EP,ETM,시/EP/*+ᆫ/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 맞	VV,*,T,맞,*,*,*,*
# 나요	EF,*,F,나요,*,*,*,*
# 제	NP,*,F,제,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 볼	VV+ETM,*,T,볼,Inflect,VV,ETM,보/VV/*+ᆯ/ETM/*
# 땐	NNG+JX,*,T,땐,Inflect,NNG,JX,때/NNG/*+ᆫ/JX/*
# 뭔가	NP+VCP+EC,*,F,뭔가,Inflect,NP,EC,뭐/NP/*+이/VCP/*+ᆫ가/EC/*
# 노	NNP,인명,F,노,*,*,*,*
# 잼	NNG,*,T,잼,*,*,*,*
# 삘이	UNKNOWN,*,*,*,*,*,*,*
# 나	VV,*,F,나,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 거	NNB,*,F,거,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 습니다	EF,*,F,습니다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# ..	SY,*,*,*,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 볼	VV+ETM,*,T,볼,Inflect,VV,ETM,보/VV/*+ᆯ/ETM/*
# 바	NNB,*,F,바,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 빅리그	NNP,*,F,빅리그,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 나온	VV+ETM,*,T,나온,Inflect,VV,ETM,나오/VV/*+ᆫ/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 게	NNB+JKS,*,F,게,Inflect,NNB,JKS,것/NNB/*+이/JKS/*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 재밌	VA,*,T,재밌,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 수	NNB,*,F,수,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 겠	EP,*,T,겠,*,*,*,*
# 네요	EF,*,F,네요,*,*,*,*
# 진짜	MAG,문장부사|양상부사,F,진짜,*,*,*,*
# 첨	NNG,*,T,첨,*,*,*,*
# 부터	JX,*,F,부터,*,*,*,*
# 끝	NNG,*,T,끝,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 지루	XR,*,F,지루,*,*,*,*
# 함	XSA+ETN,*,T,함,Inflect,XSA,ETN,하/XSA/*+ᄆ/ETN/*
# 1	SN,*,*,*,*,*,*,*
# 도	NNBC,*,F,도,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# 주인공	NNG,*,T,주인공,Compound,*,*,주인/NNG/*+공/NNG/*
# 들	XSN,*,T,들,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 발암	NNG,*,T,발암,*,*,*,*
# 캐릭터	NNG,*,F,캐릭터,*,*,*,*
# 하나	NR,*,F,하나,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# 개봉	NNG,행위,T,개봉,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 러	EC,*,F,러,*,*,*,*
# 갈	VX+ETM,*,T,갈,Inflect,VX,ETM,가/VX/*+ᆯ/ETM/*
# 예정	NNG,행위,T,예정,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 재밌	VA,*,T,재밌,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 기대	NNG,행위,F,기대,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# !	SY,*,*,*,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 중간	NNG,장소,T,중간,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 지루	XR,*,F,지루,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 부분	NNG,*,T,부분,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 거의	MAG,성분부사|정도부사,F,거의,*,*,*,*
# 대부분	NNG,정적사태,T,대부분,Compound,*,*,대/NNG/*+부분/NNG/*
# 인데	VCP+EC,*,F,인데,Inflect,VCP,EC,이/VCP/*+ᆫ데/EC/*
# 이건	NP+JX,*,T,이건,Inflect,NP,JX,이거/NP/*+ㄴ/JX/*
# 지루함	NNP,*,T,지루함,*,*,*,*
# 없이	MAG,성분부사|양태부사,F,없이,*,*,*,*
# 끝	NNG,*,T,끝,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 재밌	VA,*,T,재밌,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 본	VX+ETM,*,T,본,Inflect,VX,ETM,보/VX/*+ᆫ/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# 최근	NNG,*,T,최근,*,*,*,*
# 본	VV+ETM,*,T,본,Inflect,VV,ETM,보/VV/*+ᆫ/ETM/*
# 영화	NNG,*,F,영화,*,*,*,*
# 중	NNB,*,T,중,*,*,*,*
# 제일	MAG,*,T,제일,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !	SF,*,*,*,*,*,*,*
# !!!!!!!!!!!!!!!!!!!!!!!!!	SY,*,*,*,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 내	NP+JKG,*,F,내,Inflect,NP,JKG,나/NP/*+의/JKG/*
# 아내	NNG,*,F,아내,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 모든	MM,~명사,T,모든,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# '	SY,*,*,*,*,*,*,*
# 극한	VV+ETM,*,T,극한,Inflect,VV,ETM,극하/VV/*+ᆫ/ETM/*
# 직업	NNG,*,T,직업,*,*,*,*
# '	SY,*,*,*,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 다시	MAG,성분부사|시간부사,F,다시,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 전	MM,~명사,T,전,*,*,*,*
# 국민	NNG,*,T,국민,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 웃음바다	NNG,*,F,웃음바다,Compound,*,*,웃음/NNG/행위+바다/NNG/*
# 로	JKB,*,F,로,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 듯	EC,*,T,듯,*,*,*,*
# 합니다	VX+EF,*,F,합니다,Inflect,VX,EF,하/VX/*+ᄇ니다/EF/*
# .	SF,*,*,*,*,*,*,*
# 마약	NNG,*,T,마약,*,*,*,*
# 조직	NNG,*,T,조직,*,*,*,*
# 검거	NNG,행위,F,검거,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 치킨	VV+ETM,*,T,치킨,Inflect,VV,ETM,치키/VV/*+ᆫ/ETM/*
# 집	NNG,장소,T,집,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 잠복	NNG,행위,T,잠복,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EC,*,F,다,*,*,*,*
# 치킨	VV+ETM,*,T,치킨,Inflect,VV,ETM,치키/VV/*+ᆫ/ETM/*
# 집	NNG,*,T,집,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 인수	NNG,*,F,인수,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# 벌어지	VV,*,F,벌어지,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 해프닝	NNG,*,T,해프닝,*,*,*,*
# 속	NNG,장소,T,속,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 뿐	NNB,*,T,뿐,*,*,*,*
# 만	JX,*,T,만,*,*,*,*
# 아니	VCN,*,F,아니,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 최근	NNG,*,T,최근,*,*,*,*
# 악역	NNG,*,T,악역,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 인상	NNG,*,T,인상,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 연기	NNG,*,F,연기,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 보였	VV+EP,*,T,보였,Inflect,VV,EP,보이/VV/*+었/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 진선규	NNP,인명,F,진선규,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 대한민국	NNP,지명,T,대한민국,Compound,*,*,대한/NNG/*+민국/NNG/*
# 대표	NNG,*,F,대표,*,*,*,*
# 미녀	NNG,*,F,미녀,*,*,*,*
# 이하늬	NNP,인명,F,이하늬,*,*,*,*
# 완전히	MAG,성분부사|정도부사,F,완전히,*,*,*,*
# 웃기	VV,*,F,웃기,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 표정	NNG,*,T,표정,*,*,*,*
# 컨셉	NNG,*,T,컨셉,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 관객	NNG,*,T,관객,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 배꼽	NNG,*,T,배꼽,Compound,*,*,배/NNG/*+꼽/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 내내	MAG,성분부사|시간부사,F,내내,*,*,*,*
# 째	VV,*,F,째,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이동휘	NNP,인명,F,이동휘,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 잘생긴	VA+ETM,*,T,잘생긴,Inflect,VA,ETM,잘생기/VA/*+ᆫ/ETM/*
# 막내	NNG,*,F,막내,*,*,*,*
# 공명	NNG,*,T,공명,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# 명	NNBC,*,T,명,*,*,*,*
# 마약	NNG,*,T,마약,*,*,*,*
# 단속	NNG,행위,T,단속,*,*,*,*
# 반	NNG,*,T,반,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 펼치	VV,*,F,펼치,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 홍콩	NNP,지명,T,홍콩,*,*,*,*
# 코믹	NNG,*,T,코믹,*,*,*,*
# 스타일	NNG,*,T,스타일,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 한국	NNP,지명,T,한국,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 였	VCP+EP,*,T,였,Inflect,VCP,EP,이/VCP/*+었/EP/*
# 습니다	EF,*,F,습니다,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 동안	NNG,정적사태,T,동안,*,*,*,*
# 주성치	NNP,인명,F,주성치,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 많이	MAG,성분부사|정도부사,F,많이,*,*,*,*
# 생각났	VV+EP,*,T,생각났,Inflect,VV,EP,생각나/VV/*+았/EP/*
# 고요	EF,*,F,고요,*,*,*,*
# 이병헌	NNP,인명,T,이병헌,*,*,*,*
# 감독	NNG,*,T,감독,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 잠시	MAG,성분부사|시간부사,F,잠시,*,*,*,*
# 홍콩	NNP,지명,T,홍콩,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 유명	NNG,장소,T,유명,*,*,*,*
# 음악	NNG,*,T,음악,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 삽입	NNG,행위,T,삽입,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 며	EC,*,F,며,*,*,*,*
# 알	VV+ETM,*,T,알,Inflect,VV,ETM,알/VV/*+ᆯ/ETM/*
# 만	NNB,*,T,만,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 사람	NNG,*,T,사람,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 느낄	VV+ETM,*,T,느낄,Inflect,VV,ETM,느끼/VV/*+ᆯ/ETM/*
# 만	NNB,*,T,만,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 홍콩	NNP,지명,T,홍콩,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 한국	NNP,지명,T,한국,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 재해석	NNG,*,T,재해석,Compound,*,*,재/NNG/*+해석/NNG/행위
# 을	JKO,*,T,을,*,*,*,*
# 드러내	VV+EC,*,F,드러내,Inflect,VV,EC,드러내/VV/*+어/EC/*
# 내	VX,*,F,내,*,*,*,*
# 요	EF,*,F,요,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 배우	NNG,*,F,배우,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 코메디	NNG,*,F,코메디,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 내	NP+JKG,*,F,내,Inflect,NP,JKG,나/NP/*+의/JKG/*
# 아내	NNG,*,F,아내,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 모든	MM,~명사,T,모든,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 이미	MAG,성분부사|시간부사,F,이미,*,*,*,*
# 봤	VV+EP,*,T,봤,Inflect,VV,EP,보/VV/*+았/EP/*
# 듯이	EC,*,F,듯이,*,*,*,*
# 뭔가	NP+VCP+EC,*,F,뭔가,Inflect,NP,EC,뭐/NP/*+이/VCP/*+ᆫ가/EC/*
# 특별	NNG,정적사태,T,특별,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 느낌	NNG,정적사태,T,느낌,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 죠	EF,*,F,죠,*,*,*,*
# 영화	NNG,*,F,영화,*,*,*,*
# 중간	NNG,장소,T,중간,*,*,*,*
# 중간	NNG,장소,T,중간,*,*,*,*
# 왠지	MAG,문장부사|양상부사,F,왠지,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 웃기	VV,*,F,웃기,*,*,*,*
# 려고	EC,*,F,려고,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 무게	NNG,*,F,무게,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 잡	VV,*,T,잡,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 주	VX,*,F,주,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 악역	NNG,*,T,악역,*,*,*,*
# 신하균	NNP,인명,T,신하균,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 연기	NNG,*,F,연기,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 습니다	EF,*,F,습니다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 앰	NNP,인명,T,앰,*,*,*,*
# 블	NNG,*,T,블,*,*,*,*
# 런	NNG,*,T,런,*,*,*,*
# 스	XSN,*,F,스,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 실리	VV,*,F,실리,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 전	NNG,*,T,전,*,*,*,*
# 이동휘	NNP,인명,F,이동휘,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 하염없이	MAG,성분부사|양태부사,F,하염없이,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 쏴	MAG,성분부사|양태부사,F,쏴,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 쏴	MAG,성분부사|양태부사,F,쏴,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 외치	VV,*,F,외치,*,*,*,*
# 며	EC,*,F,며,*,*,*,*
# 관객	NNG,*,T,관객,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 배꼽	NNG,*,T,배꼽,Compound,*,*,배/NNG/*+꼽/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 마지막	NNG,*,T,마지막,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 째	VV,*,F,째,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 류승룡	NNP,인명,T,류승룡,*,*,*,*
# 진선규	NNP,인명,F,진선규,*,*,*,*
# 이하늬	NNP,인명,F,이하늬,*,*,*,*
# 이동휘	NNP,인명,F,이동휘,*,*,*,*
# 공명	NNG,*,T,공명,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 신하균	NNP,인명,T,신하균,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 펼치	VV,*,F,펼치,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 코미디	NNG,*,F,코미디,*,*,*,*
# 무비	NNG,*,F,무비,*,*,*,*
# 부부	NNG,*,F,부부,*,*,*,*
# 끼리	XSN,*,F,끼리,*,*,*,*
# 가	VV,*,F,가,*,*,*,*
# 서	EC,*,F,서,*,*,*,*
# 봐도	VX+EC,*,F,봐도,Inflect,VX,EC,보/VX/*+아도/EC/*
# 좋	VA,*,T,좋,*,*,*,*
# 겠	EP,*,T,겠,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 가족	NNG,*,T,가족,*,*,*,*
# 끼리	XSN,*,F,끼리,*,*,*,*
# 가	VV+EC,*,F,가,Inflect,VV,EC,가/VV/*+아/EC/*
# 도	JX,*,F,도,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 겠	EP,*,T,겠,*,*,*,*
# 습니다	EF,*,F,습니다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 극한	VV+ETM,*,T,극한,Inflect,VV,ETM,극하/VV/*+ᆫ/ETM/*
# 직업	NNG,*,T,직업,*,*,*,*
# "	SY,*,*,*,*,*,*,*
# 강추	NNG,*,F,강추,*,*,*,*
# 합니다	XSV+EF,*,F,합니다,Inflect,XSV,EF,하/XSV/*+ᄇ니다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
def mecabsplit(mecab_tagger,inputs, pos):
    r=[]
    inputs = mecab_tagger.parse(inputs)
    t = inputs.split('\n')[:-2]
    for i in t:
        field = i.split('\t')
        if field[1].split(',')[-1] is not '*':
            r.extend( [ (x.split('/')[0],x.split('/')[1]) for x in field[1].split(',')[-1].split('+') ] )
        else:
            r.append( (field[0],field[1].split(',')[0]) )
    if pos:
        return r
    else:
        return [ x[0] for x in r ]
    return r

# %%
# 일반 명사
nng = [word for word, tag in mecabsplit(tagger, my_sentence, True) if tag=='NNG']
# 고유 명사
nnp = [word for word, tag in mecabsplit(tagger, my_sentence, True) if tag=='NNP']

# %%
from collections import Counter,OrderedDict

# %%
# Colab에서 matplotlib 한글 깨짐 현상 해결
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
count_list=Counter(nng)
print(len(count_list))
# Out:
# 155

# %%
# counter안의 value를 sort해줌
sorted_list=count_list.most_common()
# 다시 dictionary 형태로 변환
sorted_list=OrderedDict(sorted_list)

# %%
plt.figure(figsize=(20, 10))
plt.xticks(rotation=90)
plt.plot(list(sorted_list.keys()), list(sorted_list.values()))
plt.title("일반 명사 빈도수")
plt.ylabel("# of words")
plt.xlabel("word")
plt.show()

# %%
count_list=Counter(nnp)
print(len(count_list))
# Out:
# 17

# %%
# counter안의 value를 sort해줌
sorted_list=count_list.most_common()
# 다시 dictionary 형태로 변환
sorted_list=OrderedDict(sorted_list)

# %%
plt.figure(figsize=(20, 10))
plt.xticks(rotation=90)
plt.plot(list(sorted_list.keys()), list(sorted_list.values()))
plt.title("고유 명사 빈도수")
plt.ylabel("# of words")
plt.xlabel("word")
plt.show()
